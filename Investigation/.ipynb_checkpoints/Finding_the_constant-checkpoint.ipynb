# %% [markdown]
# # Investigation the artifact effect of Tor's note
#
# In this document, we try to understand that why profile B in Tor's note do not feel exhibite boundary artifact. For EM scheme, We will use the function : $$f(Z, dt):==\frac{-(Z + Drift(Z)dt)}{Diffu(Z)}=dW $$ to find the maxmium dW to reach the boundary for Z near the boundary. And then, we will compare the probability density function of dW ~ N(0, dt) to see how like get the maximum dW or less (Remember that dW is negative).

# %%
import numpy as np
import datetime
import threading
import multiprocessing as mp
from matplotlib import pyplot as plt
from time import time
from scipy.stats import norm
# %matplotlib inline
plt.style.use('bmh')

# %% [markdown]
# ## Diffusivity profile

# %%
import sympy
z = sympy.symbols('z')
dt = sympy.symbols('dt')
K0 = sympy.symbols("K0")
K1 = 6e-3  # m / s
Aalpha = 0.5
w = 0

sym_Diffu = K0 + K1 * z * sympy.exp(-Aalpha * z)
sym_dKdz = sympy.diff(sym_Diffu, z, 1)
sym_Beta = sympy.sqrt(2 * sym_Diffu)
sym_dBdz = sympy.diff(sym_Beta, z, 1)
sym_ddBdzz = sympy.diff(sym_Beta, z, 2)
sym_Alpha = w + sym_dKdz
sym_dAdz = sympy.diff(sym_Alpha, z, 1)
sym_ddAdzz = sympy.diff(sym_Alpha, z, 2)
sym_dABdz = sympy.diff(sym_Alpha * sym_Beta, z, 1)
sym_F = -(z + sym_Alpha * dt) / sym_Beta
sym_dFdz = sympy.diff(sym_F, z, 1)
sym_F_const = -(z) / sympy.sqrt(2 * 3e-3)
sym_dFdz_const = sympy.diff(sym_F_const, z, 1)

Diffu = sympy.utilities.lambdify([z, K0], sym_Diffu, np)
dKdz = sympy.utilities.lambdify([z, K0], sym_dKdz, np)
Beta = sympy.utilities.lambdify([z, K0], sym_Beta, np)
dBdz = sympy.utilities.lambdify([z, K0], sym_dBdz, np)
ddBdzz = sympy.utilities.lambdify([z, K0], sym_ddBdzz, np)
Alpha = sympy.utilities.lambdify([z, K0], sym_Alpha, np)
dAdz = sympy.utilities.lambdify([z, K0], sym_dAdz, np)
ddAdzz = sympy.utilities.lambdify([z, K0], sym_ddAdzz, np)
dABdz = sympy.utilities.lambdify([z, K0], sym_Alpha * sym_Beta, np)
F = sympy.utilities.lambdify([z, K0 ,dt], sym_F, np)
dFdz = sympy.utilities.lambdify([z, K0, dt], sym_dFdz, np)
F_const = sympy.utilities.lambdify([z, K0, dt], sym_F_const, np)
dFdz_const = sympy.utilities.lambdify([z, K0, dt], sym_dFdz_const, np)
del z, dt, K0

# %%
# %matplotlib inline
K0=1.915e-4
dt = 10
z = np.linspace(0, 0.1, 1000)
plt.figure(figsize=(10,10))
plt.plot(z, dFdz(z, K0, dt))

# %%
# %matplotlib qt
"""
.. versionadded:: 1.1.0
   This demo depends on new features added to contourf3d.
"""

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')
#X, Y, Z = axes3d.get_test_data(0.05)
dt=10
X = np.linspace(0, 0.5, 100)
Y = np.linspace(1e-6, 3e-4, 100)
X, Y = np.meshgrid(X, Y)
Z = dFdz(X,Y,dt)
ax.plot_surface(X, Y, Z, rstride=10, cstride=10, alpha=1)

#cset = ax.contourf(X, Y, Z, 10, zdir='z', offset=-30, cmap=cm.coolwarm)
#cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
#cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
#ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
#ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-200, 100)

#ax.set_zlim(-100, 40)

#for angle in range(0, 360):
#    ax.view_init(30, angle)
#    plt.draw()
#    plt.pause(.001)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-ab78fb31b8d5> in <module>
#      18 Z = dFdz(X,Y,dt)
#      19 #ax.plot_surface(X, Y, Z, rstride=10, cstride=10, alpha=1)
# ---> 20 ax.plot_trisurf(X, Y, Z)
#      21
#      22 #cset = ax.contourf(X, Y, Z, 10, zdir='z', offset=-30, cmap=cm.coolwarm)
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_trisurf(self, color, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1943         shade = kwargs.pop('shade', cmap is None)
#    1944
# -> 1945         tri, args, kwargs = Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    1946         if 'Z' in kwargs:
#    1947             z = np.asarray(kwargs.pop('Z'))
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/tri/triangulation.py in get_from_args_and_kwargs(*args, **kwargs)
#     165             mask = kwargs.pop('mask', None)
#     166
# --> 167             triangulation = Triangulation(x, y, triangles, mask)
#     168         return triangulation, args, kwargs
#     169
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/tri/triangulation.py in __init__(self, x, y, triangles, mask)
#      53             # No triangulation specified, so use matplotlib._qhull to obtain
#      54             # Delaunay triangulation.
# ---> 55             self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      56             self.is_delaunay = True
#      57         else:
#
# RuntimeError: Error in qhull Delaunay triangulation calculation: singular input data (exitcode=2); use python verbose option (-v) to see original qhull error.

# %%
print(Z[0, :])
# Out:
# [ 1.26614540e+05  6.64186038e+02  2.19141000e+02  1.08406468e+02
#   6.29068942e+01  3.94877556e+01  2.57600084e+01  1.69994796e+01
#   1.10635998e+01  6.85861557e+00  3.77585600e+00  1.45351805e+00
#  -3.34954018e-01 -1.73754201e+00 -2.85433996e+00 -3.75506958e+00
#  -4.48952893e+00 -5.09406364e+00 -5.59570596e+00 -6.01489748e+00
#  -6.36732480e+00 -6.66518443e+00 -6.91807150e+00 -7.13361507e+00
#  -7.31793961e+00 -7.47600493e+00 -7.61185985e+00 -7.72883391e+00
#  -7.82968360e+00 -7.91670521e+00 -7.99182273e+00 -8.05665678e+00
#  -8.11257921e+00 -8.16075667e+00 -8.20218554e+00 -8.23772020e+00
#  -8.26809602e+00 -8.29394816e+00 -8.31582703e+00 -8.33421104e+00
#  -8.34951727e+00 -8.36211028e+00 -8.37230954e+00 -8.38039571e+00
#  -8.38661586e+00 -8.39118800e+00 -8.39430483e+00 -8.39613705e+00
#  -8.39683608e+00 -8.39653650e+00 -8.39535808e+00 -8.39340757e+00
#  -8.39078025e+00 -8.38756125e+00 -8.38382673e+00 -8.37964489e+00
#  -8.37507686e+00 -8.37017749e+00 -8.36499603e+00 -8.35957670e+00
#  -8.35395929e+00 -8.34817957e+00 -8.34226971e+00 -8.33625871e+00
#  -8.33017263e+00 -8.32403496e+00 -8.31786685e+00 -8.31168734e+00
#  -8.30551356e+00 -8.29936094e+00 -8.29324334e+00 -8.28717322e+00
#  -8.28116179e+00 -8.27521909e+00 -8.26935411e+00 -8.26357492e+00
#  -8.25788872e+00 -8.25230193e+00 -8.24682025e+00 -8.24144876e+00
#  -8.23619194e+00 -8.23105374e+00 -8.22603764e+00 -8.22114666e+00
#  -8.21638344e+00 -8.21175023e+00 -8.20724897e+00 -8.20288130e+00
#  -8.19864856e+00 -8.19455188e+00 -8.19059212e+00 -8.18676996e+00
#  -8.18308588e+00 -8.17954021e+00 -8.17613309e+00 -8.17286456e+00
#  -8.16973449e+00 -8.16674268e+00 -8.16388877e+00 -8.16117236e+00]

# %%
# %matplotlib qt
'''
==================
Rotating a 3D plot
==================

A very simple animation of a rotating 3D plot.

See wire3d_animation_demo for another simple example of animating a 3D plot.
'''

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# load some test data for demonstration and plot a wireframe
X, Y, Z = axes3d.get_test_data(0.1)
ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

# rotate the axes and update
for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()
    plt.pause(.001)
